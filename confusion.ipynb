# %%
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix
pred=   [1,2,3,4,5,5,4,3,2,1]
correct=[1,2,3,2,2,5,4,3,2,1]
cf = confusion_matrix(correct, pred)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.heatmap(cf, annot=True, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Correct')
plt.show()
plt.savefig("cf_plot.png")
